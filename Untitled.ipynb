# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\Ayushi Agarwal\Documents\Titanic Project\Titanic-Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#simple line plot
plt.figure(figsize=[12,7],)
plt.plot (data['Age'],data['Fare'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Customizing graph
plt.figure(figsize=[15,7],)
plt.plot(data['Age'],data['Fare'],color="yellow")
plt.xlabel("Age of Passengers")
plt.ylabel("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#scatter plot
plt.figure(figsize=[12,7],)
plt.scatter(data['Age'],data['Fare'],color='red')
plt.xlabel("Age of Passengers")
plt.ylabel("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#grouping adta by different colors
color=[]
for Sex in data['Sex']:
    if Sex=='male':
        color.append('blue')
    else:
            color.append('pink')
plt.figure(figsize=[12,7],)            
plt.scatter(data['Age'],data['Fare'],c=color)
plt.xlabel('Age of Passengers')
plt.ylabel('Fare')
plt.title('Age-Fare')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#histogram
plt.figure(figsize=[12,7],)    
plt.hist(data['Survived'])
plt.show()
 ## o/p contains 2 bars because we have only 2 o/ps as True or False

# %%
#histogram
plt.figure(figsize=[12,7],)    
plt.hist(data['Age'])
plt.show()

# %%
#Bins in histogram
plt.figure(figsize=[12,7],)    
plt.hist(data['Age'],bins = 17,color='orange')
plt.show


# Bins makes the bar thinner
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#value counts
data.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
#value count for specific columns
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
#plotting bar chart
plt.figure(figsize=[12,7],)    
data['Age'].value_counts().plot(kind='bar',color='purple')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=[12,7],)  
data['Survived'].value_counts().plot(kind='bar',color='pink')
# Out:
# <AxesSubplot:>

# %%
#countplot by seaborn library
plt.figure(figsize=[12,7],)  
sns.countplot(data=data)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize=[12,7],)  
sns.countplot(data['Age'])
# Out:
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=[12,7],)  
sns.countplot(data['Survived'])
# Out:
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=[12,7],)  
sns.countplot(data['Survived'],hue=data['Sex'])
# Out:
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#division on basis of Pclass
plt.figure(figsize=[12,7],)  
sns.countplot(data=data,x='Survived',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#scatter plot b/w survived & age with hue pclass
plt.figure(figsize=[12,7],)  
sns.scatterplot(data=data,x='Survived',y='Age',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
#barplot b/w Age & Fare
plt.figure(figsize=[12,7],)  
sns.barplot(data=data, x='Age',y='Fare',hue='Embarked')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#barplot Sex & Fare
plt.figure(figsize=[12,7],)  
sns.barplot(data=data, x='Sex',y='Fare',hue='Embarked',color='purple')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#barplot Sex & Fare
plt.figure(figsize=[12,7],)  
sns.barplot(data=data, x='Sex',y='Fare',hue='Pclass',color='blue')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#pairplot of all
# allows us to plot pairwise relationships between variables within a dataset.           # how to chnage the color?

plt.figure(figsize=[12,7],) 
sns.pairplot(data=data,vars=['Age','Survived','Sex','Fare'])

# %%
#histograms of all
 
data.hist()                                                      #how to change the size?
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#boxplot of fare &sex
plt.figure(figsize=[12,7],) 
sns.boxplot(data=data,x='Sex',y='Fare',hue='Pclass',color='green')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#boxenplot
plt.figure(figsize=[12,7],) 
sns.boxenplot(data=data,x='Sex',y='Fare',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#Swarmplot
plt.figure(figsize=[12,7],) 
sns.swarmplot(data=data,x='Sex',y='Fare',hue='Pclass',color='brown')
# Out:
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#strip plot
plt.figure(figsize=[12,7],) 
sns.stripplot(data=data,x='Sex',y='Fare',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#heatmap
plt.figure(figsize=[12,7],) 
corr=data.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
#box plot
plt.figure(figsize=[12,7],) 
sns.boxplot(data=data,x='Sex',y='Fare',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#swarm plot
plt.figure(figsize=[12,7],) 
sns.swarmplot(data=data,x='Sex',y='Fare',hue='Parch')
# Out:
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ayushi Agarwal\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#boxen plot
plt.figure(figsize=[12,7],) 
sns.boxenplot(data=data,x='Sex',y='Fare',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#strip plot
plt.figure(figsize=[12,7],) 
sns.stripplot(data=data,x='Sex',y='Fare',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#violin plot
plt.figure(figsize=[12,7],) 
sns.violinplot(data=data,x='Sex',y='Fare',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
#lm plot
plt.figure(figsize=[12,7],) 
sns.lmplot(data=data,x='Age',y='Fare')

# %% [markdown]
# graph of age below 30

# %%
#boxplot
plt.figure(figsize=[12,7],) 
sns.boxplot(data=data[data['Age']<30],x='Age',y='Fare',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#Age_growth column is added in the last
data['Age_growth']=data['Age']+10
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_growth
# 0      0         A/5 21171   7.2500   NaN        S        32.0
# 1      0          PC 17599  71.2833   C85        C        48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        36.0
# ...

# %%
#scatterplot
plt.figure(figsize=[12,7],) 
sns.scatterplot(data=data,x='Age',y='Age_growth',hue='Parch')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age_growth'>
